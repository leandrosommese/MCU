# %%
import numpy as np
import pandas as pd

# %%
path = '/home/lean/Documentos/Lean/SBG/Base_de_calcio/DiversidadConformacionalCBS/MCU/'
clinvar_results = pd.read_csv(path + 'clinvar_result.txt',sep='\t',usecols=['Name', 'Protein change','Clinical significance (Last reviewed)','Condition(s)'])

# %%
Clinical_significance = ['Conflicting interpretations','Benign','Likely benign','Uncertain significance','Likely pathogenic','Pathogenic']

# %%
clinvar_results[clinvar_results['Clinical significance (Last reviewed)'].str.contains(Clinical_significance[5])]#'|'.join(Clinical_significance[1]))]
# Out:
#                                                   Name  \
# 0    GRCh38/hg38 10q11.21-22.2(chr10:42685306-73715...
# 1    GRCh38/hg38 10q11.23-23.2(chr10:50729367-87147...
# 2    GRCh38/hg38 10q21.1-22.2(chr10:58436466-744152...
# 3    GRCh38/hg38 10q21.3-22.2(chr10:63402579-752960...
# 4    GRCh38/hg38 10q21.3-22.3(chr10:67196567-794220...
# 60                   NM_001195518.2(MICU1):c.1072-1G>A
# 61                   NM_001195518.2(MICU1):c.1072-1G>C
# 75       NM_001195518.2(MICU1):c.1042C>T (p.Gln348Ter)
# 97         NM_001195518.2(MICU1):c.900del (p.Gln300fs)
# 123                   NM_001195518.2(MICU1):c.735+1G>A
# 124        NM_001195518.2(MICU1):c.734del (p.Gln245fs)
# 133       GRCh38/hg38 10q22.1(chr10:72485363-72566418)
# 140    NM_001195518.2(MICU1):c.638_639del (p.Thr213fs)
# 146       NM_001195518.2(MICU1):c.598G>T (p.Glu200Ter)
# 151       NM_001195518.2(MICU1):c.547C>T (p.Gln183Ter)
# 159       NM_001195518.2(MICU1):c.538-1133_538-1130del
# ...
